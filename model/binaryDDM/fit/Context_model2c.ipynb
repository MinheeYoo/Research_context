# %%
import os
import hddm
import pickle
from kabuki.analyze import gelman_rubin
import kabuki
from IPython.parallel import Client
# Out:
# /Users/minheeyoo/opt/anaconda3/envs/hddmenv/lib/python3.6/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %% [markdown]
# # Description of model and data
# * z = constrained to be 0.5
# * v = v0 + v1 * tVD
#     * tVD : target value difference (higher value target - lower value target)

# %%
data = hddm.load_csv('Model2_data.csv')
data
# Out:
#       subj_idx  response       rt trialType       tVD       cVD    tVDcVD  \
# 0            1         1  0.58297        hh  0.096667  0.000000  0.000000
# 1            1         1  0.33312        ll  0.081000 -0.042222 -0.003420
# 2            1         0  0.48313        Hh  0.086667  1.833333  0.158889
# 3            1         1  0.86631        Hl  0.234333 -1.888889 -0.442630
# 4            1         1  0.54919        Hh  0.096667  1.832222  0.177115
# ...        ...       ...      ...       ...       ...       ...       ...
# 4085        24         0  0.57208        Hl  0.067333 -2.000000 -0.134667
# 4086        24         1  0.48706        ll  0.121000  0.000000  0.000000
# 4087        24         1  0.58487        ll  0.193333  0.000000  0.000000
# 4088        24         1  0.39946        hh  0.045667  0.073333  0.003349
# 4089        24         0  0.89197        Hl  0.359000 -1.992222 -0.715208
#
#          sumVD
# 0     0.096667
# 1     0.038778
# 2     1.920000
# 3    -1.654556
# 4     1.928889
# ...        ...
# 4085 -1.932667
# 4086  0.121000
# 4087  0.193333
# 4088  0.119000
# 4089 -1.633222
#
# [4090 rows x 8 columns]

# %%
def run_model(i):
    import os
    import hddm
    import pickle
    pathAnalysis = 'project'
    os.chdir(pathAnalysis)
    data = hddm.load_csv(pathAnalysis + '/' + 'Model2_data.csv')
    # Fit model
    v_reg = {'model': 'v ~ 1 + tVD', 
             'link_func': lambda x: x}
    reg_descr = [v_reg]
    m = hddm.HDDMRegressor(data, reg_descr, group_only_regressors=False)
    m.sample(10000, burn=4000, dbname='Model2c_chain%i.db'%i, db='pickle')
    return m

# %%
v = Client()[:]
jobs = v.map(run_model, range(3)) # 4 is the number of CPUs
model_set = jobs.get()
# Out:
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.

# %%
# save model set
with open('Model2c_hddm_model_set', 'wb') as f:
    pickle.dump(model_set, f)
# Out:
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.

# %%
models = kabuki.utils.concat_models(model_set)
# Out:
# WARNING: Custom link functions will not be loaded.

# %%
gelman_rubin(model_set)
# Out:
# {'a': 0.9999987086695175,
#  'a_std': 0.9999450766572455,
#  'a_subj.1': 0.9999774862417024,
#  'a_subj.2': 1.0001574042241845,
#  'a_subj.3': 0.9999623898002917,
#  'a_subj.4': 1.0001652653592241,
#  'a_subj.5': 0.9999380798161063,
#  'a_subj.6': 1.0007863510525614,
#  'a_subj.7': 1.000149397546597,
#  'a_subj.8': 1.0002659034607582,
#  'a_subj.9': 1.0001641783158877,
#  'a_subj.10': 1.0002582690076651,
#  'a_subj.11': 1.0002573443240022,
#  'a_subj.12': 1.0001655116055959,
#  'a_subj.13': 1.0000142223164976,
#  'a_subj.14': 1.0002165463804518,
#  'a_subj.15': 1.000121864706441,
#  'a_subj.16': 1.0000683466566223,
#  'a_subj.17': 0.9999173352854752,
#  'a_subj.18': 0.9999448102181296,
#  'a_subj.19': 1.0003230652029091,
#  'a_subj.20': 0.99992048346497,
#  'a_subj.21': 0.9999906291899896,
#  'a_subj.22': 0.9999660056018426,
#  'a_subj.23': 1.0003614766251432,
#  'a_subj.24': 1.0004600745076921,
#  't': 1.00122858443554,
#  't_std': 1.001840001967541,
#  't_subj.1': 1.0000787371132691,
#  't_subj.2': 1.0000929497297901,
#  't_subj.3': 0.9999324987717411,
#  't_subj.4': 1.000488374711157,
#  't_subj.5': 0.999946476347819,
#  't_subj.6': 1.0007485908537481,
#  't_subj.7': 0.9999348893849487,
#  't_subj.8': 1.000217581023311,
#  't_subj.9': 1.000401717587303,
#  't_subj.10': 1.0003011641262398,
#  't_subj.11': 1.00044221638665,
#  't_subj.12': 1.0001339618322682,
#  't_subj.13': 0.9999934830988751,
#  't_subj.14': 1.0001740506807029,
#  't_subj.15': 1.000006170980291,
#  't_subj.16': 0.9999875608274312,
#  't_subj.17': 1.0000181104847234,
#  't_subj.18': 0.9999689982553465,
#  't_subj.19': 1.0001793432251649,
#  't_subj.20': 0.9999962214716528,
#  't_subj.21': 1.0001090907016053,
#  't_subj.22': 0.9999566544227406,
#  't_subj.23': 1.0006840081944524,
#  't_subj.24': 1.0004865911853076,
#  'v_Intercept': 1.0000739008798147,
#  'v_Intercept_std': 1.0005276140771444,
#  'v_Intercept_subj.1': 0.9999982004731102,
#  'v_Intercept_subj.2': 0.9999236313474072,
#  'v_Intercept_subj.3': 1.0001205509543285,
#  'v_Intercept_subj.4': 1.0001598873786235,
#  'v_Intercept_subj.5': 1.0006517394809686,
#  'v_Intercept_subj.6': 1.001051621807971,
#  'v_Intercept_subj.7': 1.000561573787693,
#  'v_Intercept_subj.8': 0.9999823900606087,
#  'v_Intercept_subj.9': 1.0000217899340518,
#  'v_Intercept_subj.10': 1.000008726713886,
#  'v_Intercept_subj.11': 1.0000418171554921,
#  'v_Intercept_subj.12': 1.0007936342679855,
#  'v_Intercept_subj.13': 1.0000154399459622,
#  'v_Intercept_subj.14': 0.999995695281603,
#  'v_Intercept_subj.15': 1.0002275429842367,
#  'v_Intercept_subj.16': 1.000228023040752,
#  'v_Intercept_subj.17': 1.0005147478567726,
#  'v_Intercept_subj.18': 1.0002087700682394,
#  'v_Intercept_subj.19': 0.9999538746920479,
#  'v_Intercept_subj.20': 0.9999850252721029,
#  'v_Intercept_subj.21': 0.999976444369069,
#  'v_Intercept_subj.22': 1.000231630271416,
#  'v_Intercept_subj.23': 1.0000743597244361,
#  'v_Intercept_subj.24': 1.0001231005962783,
#  'v_tVD': 1.0000431569787798,
#  'v_tVD_std': 1.0000080714961006,
#  'v_tVD_subj.1': 0.9999679443198627,
#  'v_tVD_subj.2': 0.9999627693587106,
#  'v_tVD_subj.3': 1.000181834655656,
#  'v_tVD_subj.4': 1.0000755035836273,
#  'v_tVD_subj.5': 1.0010817505148946,
#  'v_tVD_subj.6': 1.000872109695228,
#  'v_tVD_subj.7': 1.0011471582841254,
#  'v_tVD_subj.8': 1.000037322068518,
#  'v_tVD_subj.9': 0.9999624912224729,
#  'v_tVD_subj.10': 1.0000335982792838,
#  'v_tVD_subj.11': 0.9999966988131518,
#  'v_tVD_subj.12': 1.0008007954623663,
#  'v_tVD_subj.13': 1.0001299012438691,
#  'v_tVD_subj.14': 0.9999193001867013,
#  'v_tVD_subj.15': 1.000205345405112,
#  'v_tVD_subj.16': 1.0001468176270458,
#  'v_tVD_subj.17': 1.0003903866828703,
#  'v_tVD_subj.18': 1.0002437753359625,
#  'v_tVD_subj.19': 1.000023626696687,
#  'v_tVD_subj.20': 0.9999720656646756,
#  'v_tVD_subj.21': 0.9999959930983183,
#  'v_tVD_subj.22': 0.9999656979462969,
#  'v_tVD_subj.23': 1.0001121494319791,
#  'v_tVD_subj.24': 1.0000802998475957}

# %%
import csv
tmp = models.dic_info
with open('Model2c_dic_info.csv', 'w') as f:  # You will need 'wb' mode in Python 2.x
    w = csv.DictWriter(f, tmp.keys())
    w.writeheader()
    w.writerow(tmp)
