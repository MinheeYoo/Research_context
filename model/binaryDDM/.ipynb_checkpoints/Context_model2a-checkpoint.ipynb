# %%
import os
import hddm
import pickle
from kabuki.analyze import gelman_rubin
import kabuki
from IPython.parallel import Client
# Out:
# /Users/minheeyoo/opt/anaconda3/envs/hddmenv/lib/python3.6/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %% [markdown]
# # Description of model and data
# * z = z0 + z1 * tVD
# * v = v0 + v1 * tVD
#     * tVD : target value difference (higher value target - lower value target)

# %%
data = hddm.load_csv('Model2_data.csv')
data
# Out:
#       subj_idx  response       rt trialType       tVD       cVD    tVDcVD
# 0            1         1  0.58297        hh  0.096667  0.000000  0.000000
# 1            1         1  0.33312        ll  0.081000 -0.042222 -0.003420
# 2            1         0  0.48313        Hh  0.086667  1.833333  0.158889
# 3            1         1  0.86631        Hl  0.234333 -1.888889 -0.442630
# 4            1         1  0.54919        Hh  0.096667  1.832222  0.177115
# ...        ...       ...      ...       ...       ...       ...       ...
# 4085        24         0  0.57208        Hl  0.067333 -2.000000 -0.134667
# 4086        24         1  0.48706        ll  0.121000  0.000000  0.000000
# 4087        24         1  0.58487        ll  0.193333  0.000000  0.000000
# 4088        24         1  0.39946        hh  0.045667  0.073333  0.003349
# 4089        24         0  0.89197        Hl  0.359000 -1.992222 -0.715208
#
# [4090 rows x 7 columns]

# %%
def run_model(i):
    import os
    import hddm
    import pickle
    pathAnalysis = 'project'
    os.chdir(pathAnalysis)
    data = hddm.load_csv(pathAnalysis + '/' + 'Model2_data.csv')
    # Fit model
    v_reg = {'model': 'v ~ 1 + tVD', 
             'link_func': lambda x: x}
    z_reg = {'model': 'z ~ 1 + tVD', 'link_func': lambda x: x}
    reg_descr = [z_reg, v_reg]
    m = hddm.HDDMRegressor(data, reg_descr,
                           include=('z'), group_only_regressors=False)
    m.sample(10000, burn=4000, dbname='Model2a_chain%i.db'%i, db='pickle')
    return m

# %%
v = Client()[:]
jobs = v.map(run_model, range(3)) # 4 is the number of CPUs
model_set = jobs.get()
# Out:
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.

# %%
# save model set
with open('Model2a_hddm_model_set', 'wb') as f:
    pickle.dump(model_set, f)
# Out:
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.

# %%
models = kabuki.utils.concat_models(model_set)
# Out:
# WARNING: Custom link functions will not be loaded.

# %%
gelman_rubin(model_set)
# Out:
# {'a': 1.0003638734288363,
#  'a_std': 1.0004633297601382,
#  'a_subj.1': 0.9999209471690568,
#  'a_subj.2': 0.9999673363501334,
#  'a_subj.3': 1.0011983721914726,
#  'a_subj.4': 1.0005563600782048,
#  'a_subj.5': 1.000643457789726,
#  'a_subj.6': 1.0004811424899076,
#  'a_subj.7': 1.000108959230936,
#  'a_subj.8': 0.9999621335637048,
#  'a_subj.9': 1.0007281105258878,
#  'a_subj.10': 0.9999606024557268,
#  'a_subj.11': 1.0000009660582265,
#  'a_subj.12': 0.9999372591787393,
#  'a_subj.13': 0.9999599695723085,
#  'a_subj.14': 1.0002712784975178,
#  'a_subj.15': 1.0000521413908396,
#  'a_subj.16': 1.0002221104770321,
#  'a_subj.17': 1.000287010631472,
#  'a_subj.18': 1.0003199971718788,
#  'a_subj.19': 1.000044223518337,
#  'a_subj.20': 0.9999718836416325,
#  'a_subj.21': 1.0005637571012607,
#  'a_subj.22': 0.9999689969208666,
#  'a_subj.23': 1.000193198765016,
#  'a_subj.24': 0.9999502816891922,
#  't': 1.0009020056856366,
#  't_std': 1.0003702550308786,
#  't_subj.1': 1.0000850997725128,
#  't_subj.2': 0.9999644269589736,
#  't_subj.3': 1.0005821873146332,
#  't_subj.4': 1.0000237211704381,
#  't_subj.5': 1.0013113100222997,
#  't_subj.6': 1.002459217677814,
#  't_subj.7': 1.0000838147835123,
#  't_subj.8': 0.9999981928351525,
#  't_subj.9': 1.0007866663068967,
#  't_subj.10': 1.0001646110051026,
#  't_subj.11': 1.0000308050477746,
#  't_subj.12': 0.999948254741457,
#  't_subj.13': 1.0000916721573627,
#  't_subj.14': 1.0006285957714502,
#  't_subj.15': 1.0000292585984514,
#  't_subj.16': 1.00019515187153,
#  't_subj.17': 0.9999267666856878,
#  't_subj.18': 1.0002081733398283,
#  't_subj.19': 0.9999675610209791,
#  't_subj.20': 0.9999678662907687,
#  't_subj.21': 1.0010743156924304,
#  't_subj.22': 1.0000747674609736,
#  't_subj.23': 1.0006189773462866,
#  't_subj.24': 0.9999493064982347,
#  'z_Intercept_trans': 1.0021077091638604,
#  'z_Intercept_std': 1.001484627451993,
#  'z_Intercept_subj_trans.1': 1.0007954774739825,
#  'z_Intercept_subj_trans.2': 1.001538419041532,
#  'z_Intercept_subj_trans.3': 1.0015703695482217,
#  'z_Intercept_subj_trans.4': 1.0005618286339604,
#  'z_Intercept_subj_trans.5': 1.0007576907184348,
#  'z_Intercept_subj_trans.6': 1.0014561815082694,
#  'z_Intercept_subj_trans.7': 1.0013621062743903,
#  'z_Intercept_subj_trans.8': 1.0002702810677424,
#  'z_Intercept_subj_trans.9': 1.0007570666924734,
#  'z_Intercept_subj_trans.10': 1.0010621629707088,
#  'z_Intercept_subj_trans.11': 1.002032339650315,
#  'z_Intercept_subj_trans.12': 1.0008858242902647,
#  'z_Intercept_subj_trans.13': 1.0014869171024368,
#  'z_Intercept_subj_trans.14': 1.0007870101291478,
#  'z_Intercept_subj_trans.15': 1.0009865758648566,
#  'z_Intercept_subj_trans.16': 1.0016601191593468,
#  'z_Intercept_subj_trans.17': 1.0010861103657565,
#  'z_Intercept_subj_trans.18': 1.0016860246804253,
#  'z_Intercept_subj_trans.19': 1.0006917996986542,
#  'z_Intercept_subj_trans.20': 1.0012784611252257,
#  'z_Intercept_subj_trans.21': 1.0011555904812364,
#  'z_Intercept_subj_trans.22': 1.0010575078129171,
#  'z_Intercept_subj_trans.23': 1.0010598640415307,
#  'z_Intercept_subj_trans.24': 1.0018059774738732,
#  'z_tVD': 1.001324746320756,
#  'z_tVD_std': 1.0129430810619922,
#  'z_tVD_subj.1': 1.0012461609996655,
#  'z_tVD_subj.2': 1.0004602065007628,
#  'z_tVD_subj.3': 1.0007729344975413,
#  'z_tVD_subj.4': 1.0017113123579973,
#  'z_tVD_subj.5': 1.002398003909209,
#  'z_tVD_subj.6': 1.0066244246620137,
#  'z_tVD_subj.7': 1.002627488556307,
#  'z_tVD_subj.8': 1.0010375755723178,
#  'z_tVD_subj.9': 1.0007226782789014,
#  'z_tVD_subj.10': 1.0034908500151978,
#  'z_tVD_subj.11': 1.0009431231960337,
#  'z_tVD_subj.12': 1.0015171619884857,
#  'z_tVD_subj.13': 1.0002237018704734,
#  'z_tVD_subj.14': 1.0003343703799135,
#  'z_tVD_subj.15': 1.0005790033013657,
#  'z_tVD_subj.16': 1.0006572068170894,
#  'z_tVD_subj.17': 1.0005983612621212,
#  'z_tVD_subj.18': 1.0013673448079854,
#  'z_tVD_subj.19': 1.0010083378746284,
#  'z_tVD_subj.20': 0.999990329776515,
#  'z_tVD_subj.21': 1.0021728384102708,
#  'z_tVD_subj.22': 1.0025895741221167,
#  'z_tVD_subj.23': 1.0010357450169893,
#  'z_tVD_subj.24': 1.000404497516141,
#  'v_Intercept': 1.000959916797198,
#  'v_Intercept_std': 1.0010709305686925,
#  'v_Intercept_subj.1': 1.0000264582000318,
#  'v_Intercept_subj.2': 1.000889740871201,
#  'v_Intercept_subj.3': 0.9999500129684361,
#  'v_Intercept_subj.4': 1.0002298090404032,
#  'v_Intercept_subj.5': 0.9999563103576787,
#  'v_Intercept_subj.6': 1.0024095666567656,
#  'v_Intercept_subj.7': 1.0007061856339767,
#  'v_Intercept_subj.8': 1.0001615378703543,
#  'v_Intercept_subj.9': 1.000180424221545,
#  'v_Intercept_subj.10': 1.000336814268841,
#  'v_Intercept_subj.11': 1.0001427085102195,
#  'v_Intercept_subj.12': 1.0003291358052246,
#  'v_Intercept_subj.13': 1.0001106203488808,
#  'v_Intercept_subj.14': 0.9999631174284249,
#  'v_Intercept_subj.15': 1.0009791461511153,
#  'v_Intercept_subj.16': 0.999932831150989,
#  'v_Intercept_subj.17': 1.0010293847167375,
#  'v_Intercept_subj.18': 1.0005432464701423,
#  'v_Intercept_subj.19': 1.0003141987723683,
#  'v_Intercept_subj.20': 1.0005731503595603,
#  'v_Intercept_subj.21': 1.0005746099969324,
#  'v_Intercept_subj.22': 1.000314380643439,
#  'v_Intercept_subj.23': 1.0000384799956663,
#  'v_Intercept_subj.24': 1.0002148572399248,
#  'v_tVD': 1.0004817558580248,
#  'v_tVD_std': 1.0001086192139195,
#  'v_tVD_subj.1': 1.000243904369132,
#  'v_tVD_subj.2': 1.000858493180498,
#  'v_tVD_subj.3': 1.0000072444602435,
#  'v_tVD_subj.4': 1.0005130216945028,
#  'v_tVD_subj.5': 1.000359062580656,
#  'v_tVD_subj.6': 1.003530907436725,
#  'v_tVD_subj.7': 1.0010839829618658,
#  'v_tVD_subj.8': 0.9999676242799727,
#  'v_tVD_subj.9': 1.0010391089250081,
#  'v_tVD_subj.10': 1.000875559864065,
#  'v_tVD_subj.11': 1.0000029450125685,
#  'v_tVD_subj.12': 1.000245117258336,
#  'v_tVD_subj.13': 0.9999709473915691,
#  'v_tVD_subj.14': 0.9999177468473863,
#  'v_tVD_subj.15': 1.000681643832861,
#  'v_tVD_subj.16': 1.0000886733173524,
#  'v_tVD_subj.17': 1.0012062506522927,
#  'v_tVD_subj.18': 1.0007748815622712,
#  'v_tVD_subj.19': 1.0003419090062338,
#  'v_tVD_subj.20': 1.000270569975975,
#  'v_tVD_subj.21': 1.0006843350085202,
#  'v_tVD_subj.22': 1.0009459382526609,
#  'v_tVD_subj.23': 0.9999996405717939,
#  'v_tVD_subj.24': 1.0003318063809994}

# %%
import csv
tmp = models.dic_info
with open('Model2a_dic_info.csv', 'w') as f:  # You will need 'wb' mode in Python 2.x
    w = csv.DictWriter(f, tmp.keys())
    w.writeheader()
    w.writerow(tmp)

# %%
ppc_data = hddm.utils.post_pred_gen(models, samples = 300)
# Out:
#  [-------------------112%-------------------] 27 of 24 complete in 2732.9 sec

# %%
ppc_data.to_csv('Model2a_PPC.csv')

# %%
# save samples
samples = models.get_traces()
samples.to_csv('Model2a_samples.csv')
