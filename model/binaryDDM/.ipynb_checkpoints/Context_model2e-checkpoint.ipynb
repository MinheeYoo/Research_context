# %%
import os
import hddm
import pickle
from kabuki.analyze import gelman_rubin
import kabuki
from IPython.parallel import Client
# Out:
# /Users/minheeyoo/opt/anaconda3/envs/hddmenv/lib/python3.6/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %% [markdown]
# # Description of model and data
# * z = z0 + z1 * sumVD
#     * sumVD: side value difference (sum of all items on higher value target side - lower value target side)
# * v = v0 + v1 * tVD
#     * tVD : target value difference (higher value target - lower value target)

# %%
data = hddm.load_csv('Model2_data.csv')
data
# Out:
#       subj_idx  response       rt trialType       tVD       cVD    tVDcVD  \
# 0            1         1  0.58297        hh  0.096667  0.000000  0.000000
# 1            1         1  0.33312        ll  0.081000 -0.042222 -0.003420
# 2            1         0  0.48313        Hh  0.086667  1.833333  0.158889
# 3            1         1  0.86631        Hl  0.234333 -1.888889 -0.442630
# 4            1         1  0.54919        Hh  0.096667  1.832222  0.177115
# ...        ...       ...      ...       ...       ...       ...       ...
# 4085        24         0  0.57208        Hl  0.067333 -2.000000 -0.134667
# 4086        24         1  0.48706        ll  0.121000  0.000000  0.000000
# 4087        24         1  0.58487        ll  0.193333  0.000000  0.000000
# 4088        24         1  0.39946        hh  0.045667  0.073333  0.003349
# 4089        24         0  0.89197        Hl  0.359000 -1.992222 -0.715208
#
#          sumVD
# 0     0.096667
# 1     0.038778
# 2     1.920000
# 3    -1.654556
# 4     1.928889
# ...        ...
# 4085 -1.932667
# 4086  0.121000
# 4087  0.193333
# 4088  0.119000
# 4089 -1.633222
#
# [4090 rows x 8 columns]

# %%
def run_model(i):
    import os
    import hddm
    import pickle
    pathAnalysis = 'project'
    os.chdir(pathAnalysis)
    data = hddm.load_csv(pathAnalysis + '/' + 'Model2_data.csv')
    # Fit model
    v_reg = {'model': 'v ~ 1 + tVD', 
             'link_func': lambda x: x}
    z_reg = {'model': 'z ~ 1 + sumVD', 'link_func': lambda x: x}
    reg_descr = [z_reg, v_reg]
    m = hddm.HDDMRegressor(data, reg_descr,
                           include=('z'), group_only_regressors=False)
    m.sample(10000, burn=4000, dbname='Model2e_chain%i.db'%i, db='pickle')
    return m

# %%
v = Client()[:]
jobs = v.map(run_model, range(3)) # 4 is the number of CPUs
model_set = jobs.get()
# Out:
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.

# %%
# save model set
with open('Model2e_hddm_model_set', 'wb') as f:
    pickle.dump(model_set, f)
# Out:
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.

# %%
models = kabuki.utils.concat_models(model_set)
# Out:
# WARNING: Custom link functions will not be loaded.

# %%
gelman_rubin(model_set)
# Out:
# {'a': 0.9999760823456587,
#  'a_std': 1.000003481546173,
#  'a_subj.1': 1.0000836856992619,
#  'a_subj.2': 0.9999251914545837,
#  'a_subj.3': 1.0000430532730302,
#  'a_subj.4': 1.0002160789535488,
#  'a_subj.5': 1.0006379479316976,
#  'a_subj.6': 0.9999246574054816,
#  'a_subj.7': 1.0000953522347318,
#  'a_subj.8': 1.0000312540772092,
#  'a_subj.9': 1.0000130537636516,
#  'a_subj.10': 0.9999866648833279,
#  'a_subj.11': 0.9999668212096294,
#  'a_subj.12': 1.0001628854481381,
#  'a_subj.13': 0.9999704908370538,
#  'a_subj.14': 1.0000174797030188,
#  'a_subj.15': 1.0000413058096491,
#  'a_subj.16': 1.0000733548151604,
#  'a_subj.17': 0.9999537254485483,
#  'a_subj.18': 0.9999260313897403,
#  'a_subj.19': 1.0001856178823902,
#  'a_subj.20': 0.9999432354890021,
#  'a_subj.21': 1.0004702276153148,
#  'a_subj.22': 0.9999190556551677,
#  'a_subj.23': 0.9999321956152531,
#  'a_subj.24': 1.0003127224185262,
#  't': 1.0002072313381916,
#  't_std': 1.0001239837473652,
#  't_subj.1': 0.999970815832182,
#  't_subj.2': 1.0001917195305663,
#  't_subj.3': 0.999980153479956,
#  't_subj.4': 1.000052197795618,
#  't_subj.5': 1.0004180364996162,
#  't_subj.6': 1.0001410994609579,
#  't_subj.7': 1.0001429490914586,
#  't_subj.8': 1.0000971306378814,
#  't_subj.9': 1.0003273902806835,
#  't_subj.10': 1.0003690674124692,
#  't_subj.11': 1.0003552878742166,
#  't_subj.12': 1.0002274419479287,
#  't_subj.13': 1.0001275589167038,
#  't_subj.14': 1.0005501739496634,
#  't_subj.15': 1.0002063760608941,
#  't_subj.16': 0.9999738654961116,
#  't_subj.17': 0.9999694883098331,
#  't_subj.18': 0.9999527982183034,
#  't_subj.19': 1.000295489918426,
#  't_subj.20': 0.9999288197427801,
#  't_subj.21': 1.0005809930630156,
#  't_subj.22': 1.0000236176516641,
#  't_subj.23': 0.9999329467597428,
#  't_subj.24': 1.000198635487957,
#  'z_Intercept_trans': 1.004990035187638,
#  'z_Intercept_std': 1.0058149795664728,
#  'z_Intercept_subj_trans.1': 1.0005098147256413,
#  'z_Intercept_subj_trans.2': 1.0014137439697781,
#  'z_Intercept_subj_trans.3': 1.0003085278255992,
#  'z_Intercept_subj_trans.4': 1.0057848548692812,
#  'z_Intercept_subj_trans.5': 1.0016946948451428,
#  'z_Intercept_subj_trans.6': 1.0011738602082974,
#  'z_Intercept_subj_trans.7': 1.0035314500030217,
#  'z_Intercept_subj_trans.8': 1.004892220208564,
#  'z_Intercept_subj_trans.9': 1.001088766251686,
#  'z_Intercept_subj_trans.10': 1.005339594278776,
#  'z_Intercept_subj_trans.11': 1.0008897751393637,
#  'z_Intercept_subj_trans.12': 1.0004481931830675,
#  'z_Intercept_subj_trans.13': 1.0005451728048296,
#  'z_Intercept_subj_trans.14': 1.0005878308498555,
#  'z_Intercept_subj_trans.15': 1.0048327605048453,
#  'z_Intercept_subj_trans.16': 1.000170278386606,
#  'z_Intercept_subj_trans.17': 1.0022659144332198,
#  'z_Intercept_subj_trans.18': 1.0018799330623402,
#  'z_Intercept_subj_trans.19': 1.0002261653190476,
#  'z_Intercept_subj_trans.20': 1.0005580219691375,
#  'z_Intercept_subj_trans.21': 1.0015289299950265,
#  'z_Intercept_subj_trans.22': 1.0003654438469125,
#  'z_Intercept_subj_trans.23': 1.002644543493118,
#  'z_Intercept_subj_trans.24': 1.0027123927625934,
#  'z_sumVD': 1.0002391023981296,
#  'z_sumVD_std': 1.000167890621057,
#  'z_sumVD_subj.1': 0.9999197232017965,
#  'z_sumVD_subj.2': 1.0001615911305863,
#  'z_sumVD_subj.3': 1.000014208471131,
#  'z_sumVD_subj.4': 0.9999657683993837,
#  'z_sumVD_subj.5': 1.0002424190902668,
#  'z_sumVD_subj.6': 1.0003251903172299,
#  'z_sumVD_subj.7': 1.0000196854483696,
#  'z_sumVD_subj.8': 1.0001160672271376,
#  'z_sumVD_subj.9': 0.9999789265342187,
#  'z_sumVD_subj.10': 0.9999230080739963,
#  'z_sumVD_subj.11': 0.9999186114592111,
#  'z_sumVD_subj.12': 1.0002327750735354,
#  'z_sumVD_subj.13': 0.9999681827763709,
#  'z_sumVD_subj.14': 1.0003974971729923,
#  'z_sumVD_subj.15': 1.0003400620378846,
#  'z_sumVD_subj.16': 1.0000385912097598,
#  'z_sumVD_subj.17': 0.999928051336256,
#  'z_sumVD_subj.18': 1.0000800509738341,
#  'z_sumVD_subj.19': 0.9999460779989294,
#  'z_sumVD_subj.20': 1.0001122504081454,
#  'z_sumVD_subj.21': 1.000027398051562,
#  'z_sumVD_subj.22': 1.0000544888545086,
#  'z_sumVD_subj.23': 0.9999309126165205,
#  'z_sumVD_subj.24': 0.9999756989517712,
#  'v_Intercept': 1.0030881335285222,
#  'v_Intercept_std': 1.0012816153962514,
#  'v_Intercept_subj.1': 1.0009207520270302,
#  'v_Intercept_subj.2': 1.001711674589554,
#  'v_Intercept_subj.3': 1.0001994089930102,
#  'v_Intercept_subj.4': 1.0016163501747213,
#  'v_Intercept_subj.5': 1.0014665812193473,
#  'v_Intercept_subj.6': 1.0000949887142248,
#  'v_Intercept_subj.7': 1.0023427873704933,
#  'v_Intercept_subj.8': 1.0024911217175168,
#  'v_Intercept_subj.9': 0.99998554153575,
#  'v_Intercept_subj.10': 1.0010781183080382,
#  'v_Intercept_subj.11': 1.0000281706389245,
#  'v_Intercept_subj.12': 1.0005688381231495,
#  'v_Intercept_subj.13': 1.0008267213558288,
#  'v_Intercept_subj.14': 1.0002009611127423,
#  'v_Intercept_subj.15': 1.0013715071825506,
#  'v_Intercept_subj.16': 1.0011746928685745,
#  'v_Intercept_subj.17': 1.0004840193216946,
#  'v_Intercept_subj.18': 1.0004817948784983,
#  'v_Intercept_subj.19': 1.0012607876506563,
#  'v_Intercept_subj.20': 1.0003582569513194,
#  'v_Intercept_subj.21': 1.0000983617573964,
#  'v_Intercept_subj.22': 1.0012929695409467,
#  'v_Intercept_subj.23': 1.0000227452949633,
#  'v_Intercept_subj.24': 1.0001722009567982,
#  'v_tVD': 1.0002452475073855,
#  'v_tVD_std': 1.0007775741610443,
#  'v_tVD_subj.1': 1.0003535678182927,
#  'v_tVD_subj.2': 1.0011226662118256,
#  'v_tVD_subj.3': 1.000342842311872,
#  'v_tVD_subj.4': 1.0003963339503985,
#  'v_tVD_subj.5': 1.0009076861257777,
#  'v_tVD_subj.6': 0.9999546851113269,
#  'v_tVD_subj.7': 1.0011845297934265,
#  'v_tVD_subj.8': 1.0023563535004791,
#  'v_tVD_subj.9': 1.0001000634473005,
#  'v_tVD_subj.10': 1.0003080531937318,
#  'v_tVD_subj.11': 1.0001308972708183,
#  'v_tVD_subj.12': 1.0004267693760827,
#  'v_tVD_subj.13': 1.0004054123253738,
#  'v_tVD_subj.14': 1.0003395607325727,
#  'v_tVD_subj.15': 1.0006078660432496,
#  'v_tVD_subj.16': 1.0005556191334817,
#  'v_tVD_subj.17': 1.000050702705052,
#  'v_tVD_subj.18': 1.0004381760899372,
#  'v_tVD_subj.19': 1.0003722436990499,
#  'v_tVD_subj.20': 1.0001439980084537,
#  'v_tVD_subj.21': 1.000175511078136,
#  'v_tVD_subj.22': 1.000443745133456,
#  'v_tVD_subj.23': 0.9999969514440713,
#  'v_tVD_subj.24': 1.000179373821007}

# %%
import csv
tmp = models.dic_info
with open('Model2e_dic_info.csv', 'w') as f:  # You will need 'wb' mode in Python 2.x
    w = csv.DictWriter(f, tmp.keys())
    w.writeheader()
    w.writerow(tmp)
