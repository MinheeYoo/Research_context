# %%
import os
import hddm
import pickle
from kabuki.analyze import gelman_rubin
import kabuki
from IPython.parallel import Client
# Out:
# /Users/minheeyoo/opt/anaconda3/envs/hddmenv/lib/python3.6/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %% [markdown]
# # Description of model and data
# * z = z0 + z1 * sumVD
#     * sumVD: side value difference (sum of all items on higher rank target side - lower rank target side)
# * v = v0 + v1 * tVD + v2 * cVD
#     * tVD : target value difference (higher rank target - lower rank target)

# %%
data = hddm.load_csv('Model2_data.csv')
data
# Out:
#       subj_idx  response       rt trialType       tVD       cVD    tVDcVD  \
# 0            1         1  0.58297        hh  0.096667  0.000000  0.000000
# 1            1         1  0.33312        ll  0.081000 -0.042222 -0.003420
# 2            1         0  0.48313        Hh  0.086667  1.833333  0.158889
# 3            1         1  0.86631        Hl  0.234333 -1.888889 -0.442630
# 4            1         1  0.54919        Hh  0.096667  1.832222  0.177115
# ...        ...       ...      ...       ...       ...       ...       ...
# 4085        24         0  0.57208        Hl  0.067333 -2.000000 -0.134667
# 4086        24         1  0.48706        ll  0.121000  0.000000  0.000000
# 4087        24         1  0.58487        ll  0.193333  0.000000  0.000000
# 4088        24         1  0.39946        hh  0.045667  0.073333  0.003349
# 4089        24         0  0.89197        Hl  0.359000 -1.992222 -0.715208
#
#          sumVD
# 0     0.096667
# 1     0.038778
# 2     1.920000
# 3    -1.654556
# 4     1.928889
# ...        ...
# 4085 -1.932667
# 4086  0.121000
# 4087  0.193333
# 4088  0.119000
# 4089 -1.633222
#
# [4090 rows x 8 columns]

# %%
def run_model(i):
    import os
    import hddm
    import pickle
    pathAnalysis = 'project'
    os.chdir(pathAnalysis)
    data = hddm.load_csv(pathAnalysis + '/' + 'Model2_data.csv')
    # Fit model
    v_reg = {'model': 'v ~ 1 + tVD + cVD', 
             'link_func': lambda x: x}
    z_reg = {'model': 'z ~ 1 + sumVD', 'link_func': lambda x: x}
    reg_descr = [z_reg, v_reg]
    m = hddm.HDDMRegressor(data, reg_descr,
                           include=('z'), group_only_regressors=False)
    m.sample(10000, burn=4000, dbname='Model2f_chain%i.db'%i, db='pickle')
    return m

# %%
v = Client()[:]
jobs = v.map(run_model, range(3)) # 4 is the number of CPUs
model_set = jobs.get()
# Out:
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.

# %%
# save model set
with open('Model2f_hddm_model_set', 'wb') as f:
    pickle.dump(model_set, f)
# Out:
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.

# %%
models = kabuki.utils.concat_models(model_set)
# Out:
# WARNING: Custom link functions will not be loaded.

# %%
gelman_rubin(model_set)
# Out:
# {'a': 1.0004535217879986,
#  'a_std': 1.0001865331303557,
#  'a_subj.1': 0.9999736187920439,
#  'a_subj.2': 1.0000154329875368,
#  'a_subj.3': 1.0001882194780818,
#  'a_subj.4': 1.0003694924300288,
#  'a_subj.5': 1.0000670987692353,
#  'a_subj.6': 0.9999725166348711,
#  'a_subj.7': 1.0000023358237509,
#  'a_subj.8': 1.0002443752152643,
#  'a_subj.9': 0.999988929181933,
#  'a_subj.10': 1.000130746926125,
#  'a_subj.11': 1.0002528861400806,
#  'a_subj.12': 0.9999782830880931,
#  'a_subj.13': 1.0001528657733973,
#  'a_subj.14': 1.0034857806483124,
#  'a_subj.15': 1.0003797951010571,
#  'a_subj.16': 1.0000830793397417,
#  'a_subj.17': 0.9999561745247731,
#  'a_subj.18': 1.0003880811981674,
#  'a_subj.19': 1.0004179176717358,
#  'a_subj.20': 1.0001221363556763,
#  'a_subj.21': 0.9999777897334119,
#  'a_subj.22': 1.0003344217752548,
#  'a_subj.23': 1.0001188080871244,
#  'a_subj.24': 1.0005549216448282,
#  't': 1.0001339629748907,
#  't_std': 1.0006077355628311,
#  't_subj.1': 1.000782549497987,
#  't_subj.2': 1.0001176960626157,
#  't_subj.3': 1.0001422819036512,
#  't_subj.4': 1.000277135420238,
#  't_subj.5': 1.0002376574151923,
#  't_subj.6': 1.0002294796852864,
#  't_subj.7': 1.0000134474479025,
#  't_subj.8': 0.9999225243106533,
#  't_subj.9': 0.9999176120598683,
#  't_subj.10': 1.0004285416099425,
#  't_subj.11': 1.0006017038986434,
#  't_subj.12': 1.0001446270299503,
#  't_subj.13': 0.9999240440550511,
#  't_subj.14': 1.0072609608046326,
#  't_subj.15': 1.0003198008653809,
#  't_subj.16': 1.000533315161812,
#  't_subj.17': 1.0002653925210436,
#  't_subj.18': 1.0006616035728235,
#  't_subj.19': 1.0003582758634109,
#  't_subj.20': 1.0007495432481215,
#  't_subj.21': 0.9999208725552082,
#  't_subj.22': 1.0008551124634106,
#  't_subj.23': 1.000660952419754,
#  't_subj.24': 1.0004574379192568,
#  'z_Intercept_trans': 1.032077301305145,
#  'z_Intercept_std': 1.0058903390835787,
#  'z_Intercept_subj_trans.1': 1.0094368661753204,
#  'z_Intercept_subj_trans.2': 1.0083977914767823,
#  'z_Intercept_subj_trans.3': 1.0134498806224392,
#  'z_Intercept_subj_trans.4': 1.0014768439052713,
#  'z_Intercept_subj_trans.5': 1.0049627134270671,
#  'z_Intercept_subj_trans.6': 1.0095553876110233,
#  'z_Intercept_subj_trans.7': 1.0046071789652167,
#  'z_Intercept_subj_trans.8': 1.0039454120751263,
#  'z_Intercept_subj_trans.9': 1.0120445802167932,
#  'z_Intercept_subj_trans.10': 1.0026566539988138,
#  'z_Intercept_subj_trans.11': 1.0086869697909053,
#  'z_Intercept_subj_trans.12': 1.0098171606626165,
#  'z_Intercept_subj_trans.13': 1.0075716896228735,
#  'z_Intercept_subj_trans.14': 1.0101050440930823,
#  'z_Intercept_subj_trans.15': 1.0058934224511196,
#  'z_Intercept_subj_trans.16': 1.0112399880093006,
#  'z_Intercept_subj_trans.17': 1.0082534534614382,
#  'z_Intercept_subj_trans.18': 1.0056387138807195,
#  'z_Intercept_subj_trans.19': 1.0118139748835708,
#  'z_Intercept_subj_trans.20': 1.008656888808235,
#  'z_Intercept_subj_trans.21': 1.0084194534598137,
#  'z_Intercept_subj_trans.22': 1.01261694202821,
#  'z_Intercept_subj_trans.23': 1.0067526487335332,
#  'z_Intercept_subj_trans.24': 1.0101632388870228,
#  'z_sumVD': 1.0000406377861535,
#  'z_sumVD_std': 1.0001598964464957,
#  'z_sumVD_subj.1': 1.0005130673088978,
#  'z_sumVD_subj.2': 1.0002125500599512,
#  'z_sumVD_subj.3': 1.0000861766802869,
#  'z_sumVD_subj.4': 1.000162763602307,
#  'z_sumVD_subj.5': 1.0000357503628357,
#  'z_sumVD_subj.6': 0.9999602146544441,
#  'z_sumVD_subj.7': 1.0000795285208868,
#  'z_sumVD_subj.8': 1.0000602641709466,
#  'z_sumVD_subj.9': 1.0004005555754116,
#  'z_sumVD_subj.10': 0.9999576955551558,
#  'z_sumVD_subj.11': 0.9999583708653392,
#  'z_sumVD_subj.12': 0.9999488575926303,
#  'z_sumVD_subj.13': 0.9999715401584176,
#  'z_sumVD_subj.14': 1.0020401955003375,
#  'z_sumVD_subj.15': 1.0003252684951889,
#  'z_sumVD_subj.16': 1.0001689646524963,
#  'z_sumVD_subj.17': 1.0000290450500335,
#  'z_sumVD_subj.18': 1.0000643280232469,
#  'z_sumVD_subj.19': 1.0003486713443672,
#  'z_sumVD_subj.20': 1.0004721727923356,
#  'z_sumVD_subj.21': 0.9999199369532888,
#  'z_sumVD_subj.22': 1.000175451860723,
#  'z_sumVD_subj.23': 0.9999538039371674,
#  'z_sumVD_subj.24': 0.9999788710884012,
#  'v_Intercept': 1.0046298156370312,
#  'v_Intercept_std': 1.0009469622940301,
#  'v_Intercept_subj.1': 1.0007917527543622,
#  'v_Intercept_subj.2': 1.0011424693598305,
#  'v_Intercept_subj.3': 1.0010839069026634,
#  'v_Intercept_subj.4': 0.9999383595068979,
#  'v_Intercept_subj.5': 1.0004168103511608,
#  'v_Intercept_subj.6': 1.0020040695179329,
#  'v_Intercept_subj.7': 1.0004382312634859,
#  'v_Intercept_subj.8': 1.0001265850695822,
#  'v_Intercept_subj.9': 1.00115568666606,
#  'v_Intercept_subj.10': 1.0001439593397892,
#  'v_Intercept_subj.11': 1.0019049813075558,
#  'v_Intercept_subj.12': 1.0015608765408845,
#  'v_Intercept_subj.13': 1.0014343064673212,
#  'v_Intercept_subj.14': 1.000962447052761,
#  'v_Intercept_subj.15': 1.0019389251268014,
#  'v_Intercept_subj.16': 1.0006417500757074,
#  'v_Intercept_subj.17': 1.0009913782604891,
#  'v_Intercept_subj.18': 1.0027797895797341,
#  'v_Intercept_subj.19': 1.0004633367957438,
#  'v_Intercept_subj.20': 1.0006223045281912,
#  'v_Intercept_subj.21': 1.000170195693079,
#  'v_Intercept_subj.22': 1.0031602340815935,
#  'v_Intercept_subj.23': 1.0007598444649084,
#  'v_Intercept_subj.24': 1.000738410625309,
#  'v_tVD': 1.0007644054192173,
#  'v_tVD_std': 1.0003112990318335,
#  'v_tVD_subj.1': 1.0002734805736204,
#  'v_tVD_subj.2': 1.000127504068236,
#  'v_tVD_subj.3': 0.9999827422515897,
#  'v_tVD_subj.4': 0.9999486257624558,
#  'v_tVD_subj.5': 0.9999959223907087,
#  'v_tVD_subj.6': 1.0002217471602683,
#  'v_tVD_subj.7': 0.9999905625656337,
#  'v_tVD_subj.8': 1.0002226103797107,
#  'v_tVD_subj.9': 0.9999347203098614,
#  'v_tVD_subj.10': 0.9999741150898257,
#  'v_tVD_subj.11': 1.0008153697128632,
#  'v_tVD_subj.12': 1.0000898256858946,
#  'v_tVD_subj.13': 1.0004616335064191,
#  'v_tVD_subj.14': 1.0009994934310904,
#  'v_tVD_subj.15': 1.0003935467989324,
#  'v_tVD_subj.16': 1.0000409295870951,
#  'v_tVD_subj.17': 1.0002668532596284,
#  'v_tVD_subj.18': 1.0012470447084394,
#  'v_tVD_subj.19': 0.9999574446778885,
#  'v_tVD_subj.20': 0.9999703821099009,
#  'v_tVD_subj.21': 0.9999904210099476,
#  'v_tVD_subj.22': 1.0011058996035391,
#  'v_tVD_subj.23': 1.0004411233808537,
#  'v_tVD_subj.24': 0.9999363983532682,
#  'v_cVD': 1.0000319442901913,
#  'v_cVD_std': 1.0009168923507157,
#  'v_cVD_subj.1': 1.0007144021156729,
#  'v_cVD_subj.2': 1.000114747422598,
#  'v_cVD_subj.3': 1.0001828138976676,
#  'v_cVD_subj.4': 1.000052830708483,
#  'v_cVD_subj.5': 1.0000910650434458,
#  'v_cVD_subj.6': 0.9999734779699462,
#  'v_cVD_subj.7': 1.0002609440205439,
#  'v_cVD_subj.8': 0.9999797645833182,
#  'v_cVD_subj.9': 0.9999455499455849,
#  'v_cVD_subj.10': 1.000068306702025,
#  'v_cVD_subj.11': 1.0001105541854138,
#  'v_cVD_subj.12': 1.000047522510357,
#  'v_cVD_subj.13': 1.0000270294443687,
#  'v_cVD_subj.14': 1.0001993076056794,
#  'v_cVD_subj.15': 0.9999733329430517,
#  'v_cVD_subj.16': 1.0001400726801628,
#  'v_cVD_subj.17': 0.999936764284786,
#  'v_cVD_subj.18': 0.9999422204188734,
#  'v_cVD_subj.19': 1.0005518060850105,
#  'v_cVD_subj.20': 1.0004543845091087,
#  'v_cVD_subj.21': 1.00015016550309,
#  'v_cVD_subj.22': 1.000245472288794,
#  'v_cVD_subj.23': 0.9999204120592976,
#  'v_cVD_subj.24': 1.000022579233353}

# %%
import csv
tmp = models.dic_info
with open('Model2f_dic_info.csv', 'w') as f:  # You will need 'wb' mode in Python 2.x
    w = csv.DictWriter(f, tmp.keys())
    w.writeheader()
    w.writerow(tmp)

# %%
ppc_data = hddm.utils.post_pred_gen(models, samples = 500)
# Out:
#  [-------------------112%-------------------] 27 of 24 complete in 4164.4 sec

# %%
ppc_data.to_csv('Model2f_PPC.csv')
