# %%
import os
import hddm
import pickle
from kabuki.analyze import gelman_rubin
import kabuki
from IPython.parallel import Client
# Out:
# /Users/minheeyoo/opt/anaconda3/envs/hddmenv/lib/python3.6/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %% [markdown]
# # Description of model and data
# * z = z0 + z1 * tVD
# * v = v0 + v1 * tVD + v2 * cVD
#     * tVD : target value difference (higher value target - lower value target)

# %%
data = hddm.load_csv('Model2_data.csv')
data
# Out:
#       subj_idx  response       rt trialType       tVD       cVD    tVDcVD
# 0            1         1  0.58297        hh  0.096667  0.000000  0.000000
# 1            1         1  0.33312        ll  0.081000 -0.042222 -0.003420
# 2            1         0  0.48313        Hh  0.086667  1.833333  0.158889
# 3            1         1  0.86631        Hl  0.234333 -1.888889 -0.442630
# 4            1         1  0.54919        Hh  0.096667  1.832222  0.177115
# ...        ...       ...      ...       ...       ...       ...       ...
# 4085        24         0  0.57208        Hl  0.067333 -2.000000 -0.134667
# 4086        24         1  0.48706        ll  0.121000  0.000000  0.000000
# 4087        24         1  0.58487        ll  0.193333  0.000000  0.000000
# 4088        24         1  0.39946        hh  0.045667  0.073333  0.003349
# 4089        24         0  0.89197        Hl  0.359000 -1.992222 -0.715208
#
# [4090 rows x 7 columns]

# %%
def run_model(i):
    import os
    import hddm
    import pickle
    pathAnalysis = 'project'
    os.chdir(pathAnalysis)
    data = hddm.load_csv(pathAnalysis + '/' + 'Model2_data.csv')
    # Fit model
    v_reg = {'model': 'v ~ 1 + tVD + cVD', 
             'link_func': lambda x: x}
    z_reg = {'model': 'z ~ 1 + tVD', 'link_func': lambda x: x}
    reg_descr = [z_reg, v_reg]
    m = hddm.HDDMRegressor(data, reg_descr,
                           include=('z'), group_only_regressors=False)
    m.sample(10000, burn=4000, dbname='Model2b_chain%i.db'%i, db='pickle')
    return m

# %%
v = Client()[:]
jobs = v.map(run_model, range(3)) # 4 is the number of CPUs
model_set = jobs.get()
# Out:
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.

# %%
# save model set
with open('Model2b_hddm_model_set', 'wb') as f:
    pickle.dump(model_set, f)
# Out:
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.

# %%
models = kabuki.utils.concat_models(model_set)
# Out:
# WARNING: Custom link functions will not be loaded.

# %%
gelman_rubin(model_set)
# Out:
# {'a': 1.0001930746679082,
#  'a_std': 1.0000153070290914,
#  'a_subj.1': 0.999927503578906,
#  'a_subj.2': 1.0000857578999442,
#  'a_subj.3': 0.9999631895508426,
#  'a_subj.4': 0.9999951657619403,
#  'a_subj.5': 1.0005566399697623,
#  'a_subj.6': 0.9999589715155826,
#  'a_subj.7': 1.0001070156729743,
#  'a_subj.8': 1.0005701540513077,
#  'a_subj.9': 1.0001157044683853,
#  'a_subj.10': 1.0002255989653654,
#  'a_subj.11': 1.000805636004395,
#  'a_subj.12': 1.0001544984212467,
#  'a_subj.13': 1.0000617097247795,
#  'a_subj.14': 0.9999348297791638,
#  'a_subj.15': 0.99995509221888,
#  'a_subj.16': 0.999948626307959,
#  'a_subj.17': 0.9999279127880426,
#  'a_subj.18': 0.9999957283147469,
#  'a_subj.19': 1.000084294511052,
#  'a_subj.20': 1.0007508154538636,
#  'a_subj.21': 1.0005568573788328,
#  'a_subj.22': 0.9999729559129115,
#  'a_subj.23': 1.0004686613976925,
#  'a_subj.24': 1.0006511249230916,
#  't': 1.0001295903565568,
#  't_std': 1.000042683915024,
#  't_subj.1': 1.0000396136645588,
#  't_subj.2': 1.0002526363309647,
#  't_subj.3': 1.0000021641685122,
#  't_subj.4': 1.0002957031528652,
#  't_subj.5': 1.0003825014346728,
#  't_subj.6': 1.0007120968014498,
#  't_subj.7': 1.0001863227953134,
#  't_subj.8': 1.0002985053377336,
#  't_subj.9': 1.0000345068114804,
#  't_subj.10': 1.0004721516645003,
#  't_subj.11': 1.001322914516577,
#  't_subj.12': 0.9999239377406413,
#  't_subj.13': 1.0000703077356965,
#  't_subj.14': 0.9999430867594018,
#  't_subj.15': 0.9999915444200513,
#  't_subj.16': 1.0001210427476008,
#  't_subj.17': 0.9999755400540342,
#  't_subj.18': 0.9999466133058276,
#  't_subj.19': 1.0000841870254364,
#  't_subj.20': 1.0005842080786875,
#  't_subj.21': 1.0002994708839408,
#  't_subj.22': 1.000120250159744,
#  't_subj.23': 1.0005420433692256,
#  't_subj.24': 1.000606642365046,
#  'z_Intercept_trans': 1.0049749291372425,
#  'z_Intercept_std': 1.0126828084232697,
#  'z_Intercept_subj_trans.1': 1.0031798873439766,
#  'z_Intercept_subj_trans.2': 1.0023966470557348,
#  'z_Intercept_subj_trans.3': 1.0033985160665615,
#  'z_Intercept_subj_trans.4': 1.004126924231024,
#  'z_Intercept_subj_trans.5': 1.0026828842188333,
#  'z_Intercept_subj_trans.6': 1.0027849960493342,
#  'z_Intercept_subj_trans.7': 1.0029887317039432,
#  'z_Intercept_subj_trans.8': 1.0037268154936805,
#  'z_Intercept_subj_trans.9': 1.0023681011435022,
#  'z_Intercept_subj_trans.10': 1.0036644112673432,
#  'z_Intercept_subj_trans.11': 1.0036279494109217,
#  'z_Intercept_subj_trans.12': 1.0032336444666814,
#  'z_Intercept_subj_trans.13': 1.0044347129212494,
#  'z_Intercept_subj_trans.14': 1.0043563615286006,
#  'z_Intercept_subj_trans.15': 1.0025880589050047,
#  'z_Intercept_subj_trans.16': 1.0038666603442998,
#  'z_Intercept_subj_trans.17': 1.0023424797507148,
#  'z_Intercept_subj_trans.18': 1.003748137645714,
#  'z_Intercept_subj_trans.19': 1.0037283196026217,
#  'z_Intercept_subj_trans.20': 1.0023518403609584,
#  'z_Intercept_subj_trans.21': 1.0039193789826633,
#  'z_Intercept_subj_trans.22': 1.0044633125283113,
#  'z_Intercept_subj_trans.23': 1.0023746822803543,
#  'z_Intercept_subj_trans.24': 1.0022946682484315,
#  'z_tVD': 1.0052290335525909,
#  'z_tVD_std': 1.0175571595980517,
#  'z_tVD_subj.1': 1.0013229644530994,
#  'z_tVD_subj.2': 1.0005317199715829,
#  'z_tVD_subj.3': 1.0001153087733254,
#  'z_tVD_subj.4': 1.0047387198033826,
#  'z_tVD_subj.5': 1.004782985278075,
#  'z_tVD_subj.6': 1.006306840796704,
#  'z_tVD_subj.7': 1.0026511078735543,
#  'z_tVD_subj.8': 1.0039429292409048,
#  'z_tVD_subj.9': 1.0011488454654407,
#  'z_tVD_subj.10': 1.0069459657421922,
#  'z_tVD_subj.11': 1.0033162316136344,
#  'z_tVD_subj.12': 1.0049423716623553,
#  'z_tVD_subj.13': 1.0004287051001697,
#  'z_tVD_subj.14': 0.9999938218672779,
#  'z_tVD_subj.15': 1.0026767669781826,
#  'z_tVD_subj.16': 1.002547752936696,
#  'z_tVD_subj.17': 1.0027257450260085,
#  'z_tVD_subj.18': 1.0043223631250644,
#  'z_tVD_subj.19': 1.0009673539724733,
#  'z_tVD_subj.20': 1.0002151722906207,
#  'z_tVD_subj.21': 1.0049886081124801,
#  'z_tVD_subj.22': 1.001956149775039,
#  'z_tVD_subj.23': 1.0019331183454119,
#  'z_tVD_subj.24': 1.0020886984493,
#  'v_Intercept': 1.0014152428840568,
#  'v_Intercept_std': 1.000854423133928,
#  'v_Intercept_subj.1': 1.0007685434746358,
#  'v_Intercept_subj.2': 1.0006426523710128,
#  'v_Intercept_subj.3': 1.001566274703413,
#  'v_Intercept_subj.4': 1.001041872173239,
#  'v_Intercept_subj.5': 1.00113416003701,
#  'v_Intercept_subj.6': 1.000175831792657,
#  'v_Intercept_subj.7': 1.0001950242030473,
#  'v_Intercept_subj.8': 1.0000796961388572,
#  'v_Intercept_subj.9': 1.000061466811552,
#  'v_Intercept_subj.10': 1.0002454038303186,
#  'v_Intercept_subj.11': 1.0001177695181114,
#  'v_Intercept_subj.12': 1.0004695515755238,
#  'v_Intercept_subj.13': 1.0000416623214123,
#  'v_Intercept_subj.14': 1.0011661086324952,
#  'v_Intercept_subj.15': 1.0006454598620251,
#  'v_Intercept_subj.16': 1.0000028676263866,
#  'v_Intercept_subj.17': 1.0000411522729697,
#  'v_Intercept_subj.18': 1.0004711710828633,
#  'v_Intercept_subj.19': 1.002655108454386,
#  'v_Intercept_subj.20': 1.0020926138432509,
#  'v_Intercept_subj.21': 1.0005132543579147,
#  'v_Intercept_subj.22': 1.0007628888132731,
#  'v_Intercept_subj.23': 1.0000726360971566,
#  'v_Intercept_subj.24': 0.9999541431250509,
#  'v_tVD': 1.000660532838711,
#  'v_tVD_std': 1.0003919484099708,
#  'v_tVD_subj.1': 1.0002495721922338,
#  'v_tVD_subj.2': 1.0001041209148596,
#  'v_tVD_subj.3': 1.0002017591161392,
#  'v_tVD_subj.4': 1.000961324184791,
#  'v_tVD_subj.5': 1.0008008863744915,
#  'v_tVD_subj.6': 1.0003534753750842,
#  'v_tVD_subj.7': 1.000681733477693,
#  'v_tVD_subj.8': 0.9999777175945576,
#  'v_tVD_subj.9': 0.9999430952186231,
#  'v_tVD_subj.10': 1.0009696970924484,
#  'v_tVD_subj.11': 1.0001330032740574,
#  'v_tVD_subj.12': 1.0003561773971215,
#  'v_tVD_subj.13': 1.0002116506718977,
#  'v_tVD_subj.14': 1.0001470663599321,
#  'v_tVD_subj.15': 1.0007272346885623,
#  'v_tVD_subj.16': 0.9999812563460596,
#  'v_tVD_subj.17': 1.0001758562245096,
#  'v_tVD_subj.18': 1.0014028050753807,
#  'v_tVD_subj.19': 1.0010194568295878,
#  'v_tVD_subj.20': 1.002050963078247,
#  'v_tVD_subj.21': 1.0012580481584428,
#  'v_tVD_subj.22': 1.0002021843080662,
#  'v_tVD_subj.23': 1.0000121996540294,
#  'v_tVD_subj.24': 1.0002410820992478,
#  'v_cVD': 1.0002463333293452,
#  'v_cVD_std': 0.9999169831170294,
#  'v_cVD_subj.1': 1.0004636757338858,
#  'v_cVD_subj.2': 0.9999631207569916,
#  'v_cVD_subj.3': 0.99996345698691,
#  'v_cVD_subj.4': 0.999940364289118,
#  'v_cVD_subj.5': 0.9999490146246152,
#  'v_cVD_subj.6': 1.0001489989752934,
#  'v_cVD_subj.7': 0.9999219839432161,
#  'v_cVD_subj.8': 1.0000476969979755,
#  'v_cVD_subj.9': 1.0001069716148523,
#  'v_cVD_subj.10': 0.9999803690758089,
#  'v_cVD_subj.11': 1.0000528341742219,
#  'v_cVD_subj.12': 1.0000019213983358,
#  'v_cVD_subj.13': 1.000202459073655,
#  'v_cVD_subj.14': 0.9999238836611392,
#  'v_cVD_subj.15': 1.0000411861376934,
#  'v_cVD_subj.16': 0.999970870741964,
#  'v_cVD_subj.17': 1.0000130274927832,
#  'v_cVD_subj.18': 1.0000085673100045,
#  'v_cVD_subj.19': 1.0000007555999217,
#  'v_cVD_subj.20': 1.0000665437321914,
#  'v_cVD_subj.21': 1.0001150237613825,
#  'v_cVD_subj.22': 0.9999654322437004,
#  'v_cVD_subj.23': 1.0000035785880972,
#  'v_cVD_subj.24': 1.000113001476254}

# %%
import csv
tmp = models.dic_info
with open('Model2b_dic_info.csv', 'w') as f:  # You will need 'wb' mode in Python 2.x
    w = csv.DictWriter(f, tmp.keys())
    w.writeheader()
    w.writerow(tmp)

# %%
ppc_data = hddm.utils.post_pred_gen(models, samples = 300)
# Out:
#  [-------------------112%-------------------] 27 of 24 complete in 2755.8 sec

# %%
ppc_data.to_csv('Model2b_PPC.csv')

# %%
# save samples
samples = models.get_traces()
samples.to_csv('Model2b_samples.csv')
